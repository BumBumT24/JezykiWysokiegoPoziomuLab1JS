# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
print(tf.__version__)
# Out:
# 2.18.0

# %%
training_data = np.load('TF_dataset.npz')
input_size = 2
output_size = 1

# %%
model = tf.keras.Sequential([tf.keras.layers.Dense(5,activation="sigmoid"),tf.keras.layers.Dense(5,activation="sigmoid"),tf.keras.layers.Dense(output_size)])
model.compile(optimizer='sgd', loss='mean_squared_error')
model.fit(training_data['inputs'], training_data['targets'], epochs=100, verbose=1)
# Out:
# Epoch 1/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 402.9834
# Epoch 2/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 241.2069
# Epoch 3/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 149.8171
# Epoch 4/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 114.4510
# Epoch 5/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 95.5884
# Epoch 6/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 69.8322
# Epoch 7/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 63.8989
# Epoch 8/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 63.1676
# Epoch 9/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 50.4116
# Epoch 10/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 56.0472
# Epoch 11/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 47.7522
# Epoch 12/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 53.5072
# Epoch 13/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 46.5883
# Epoch 14/100
# ...

# %%
model.layers[0].get_weights()
# Out:
# [array([[-0.75427634, -0.57797056,  0.3672375 , -0.67201596, -0.531981  ],
#         [ 1.1277337 ,  1.1719089 , -0.55230325,  1.1283519 ,  0.8609293 ]],
#        dtype=float32),
#  array([ 8.302134 ,  1.4133363, -2.4418802, -5.137143 , -7.1170726],
#        dtype=float32)]

# %%
model.predict_on_batch(training_data['inputs']).round(1)
# Out:
# array([[ 13.6],
#        [-11.2],
#        [ 41.7],
#        [ 29.6],
#        [-15.1],
#        [ -2.8],
#        [ 41.2],
#        [ 34.6],
#        [ -2.7],
#        [-30. ],
#        [-26.8],
#        [ 30.5],
#        [ 41.5],
#        [ 19.4],
#        [ 41.6],
#        [ 11.5],
#        [-11.3],
#        [-29.8],
#        [ 41.5],
#        [ 17.8],
#        [ 38.6],
#        [-10.4],
#        [-10.2],
#        [ -1.5],
#        [  8.2],
#        [ 11.6],
#        [ -4.1],
#        [ -6.6],
#        [ 39. ],
#        [ -6.4],
#        [ 38.8],
#        [-19.9],
#        [-30.2],
#        [ 15.5],
#        [-16.1],
#        [ 41.6],
#        [ 18.3],
#        [-20.8],
#        [-30.1],
#        [ 40.3],
#        [ 33.7],
#        [ -5.2],
#        [-17.6],
#        [ 41.6],
#        [-14.5],
#        [ -0.7],
#        [  3. ],
#        [ 36.9],
#        [-26.9],
#        [-20.8],
#        [-30.1],
#        [ 17.8],
#        [ 18.4],
#        [ -1.7],
#        [-23.9],
# ...

# %%
plt.plot(np.squeeze(model.predict_on_batch(training_data['inputs'])),np.squeeze(training_data['targets']), color="blue")
plt.xlabel('outputs')
plt.ylabel('targets')
plt.show()
